# %%
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
# 파일 처리
# 파일 불러오기 1
df = pd.read_csv('data/PS_part_aa.csv')

# %%
df
# Out:
#         step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT    9839.64  C1231006815       170136.0       160296.36
# 1          1   PAYMENT    1864.28  C1666544295        21249.0        19384.72
# 2          1  TRANSFER     181.00  C1305486145          181.0            0.00
# 3          1  CASH_OUT     181.00   C840083671          181.0            0.00
# 4          1   PAYMENT   11668.14  C2048537720        41554.0        29885.86
# ...      ...       ...        ...          ...            ...             ...
# 614225    34   PAYMENT   19241.41   C474159361       100801.0        81559.59
# 614226    34  CASH_OUT   34988.73  C2117483954       136817.0       101828.27
# 614227    34   CASH_IN  291261.85   C190415762       153837.0       445098.85
# 614228    34  CASH_OUT   93812.38   C257300713        90746.0            0.00
# 614229    34   PAYMENT   21861.95   C399181300            NaN             NaN
#
# ...

# %%
# 파일 처리
# 파일 불러오기 2
filename = '../data/PS_20174392719_1491204439457_log.csv'
df = pd.read_csv(filename)

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
# 파일 처리
# 파일 저장하기 1
df.to_csv('../data/2021_03_data.csv', index = None)

# %%
df2 = pd.read_csv('../data/2021_03_data.csv')

# %%
df2
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
# 데이터프레임 확인 하기
# 첫 5개 데이터
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
# 데이터프레임 확인 하기
# 첫 10개 데이터
df.head(10)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4     1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5     1   PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6     1   PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7     1   PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8     1   PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9     1     DEBIT   5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0            0.00        0               0
# ...

# %%
# 데이터프레임 확인 하기
# 마지막 5개 데이터
df.tail()
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 6362615             0.0   C776919290            0.00       339682.13        1
# 6362616             0.0  C1881841831            0.00            0.00        1
# 6362617             0.0  C1365125890        68488.84      6379898.11        1
# 6362618             0.0  C2080388513            0.00            0.00        1
# 6362619             0.0   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 6362615               0
# 6362616               0
# 6362617               0
# ...

# %%
# 데이터프레임 확인 하기
# 데이터프레임 크기 (행, 열)
df.shape
# Out:
# (6362620, 11)

# %%
# 데이터프레임 확인 하기
# 데이터프레임 요약
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
# 일부 데이터 선택 1
# 데이터프레임 -> 시리즈
df['step']
# Out:
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
#           ...
# 6362615    743
# 6362616    743
# 6362617    743
# 6362618    743
# 6362619    743
# Name: step, Length: 6362620, dtype: int64

# %%
# 일부 데이터 선택 2
# 데이터프레임 -> 데이터프레임
df[['step']]
# Out:
#          step
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 6362615   743
# 6362616   743
# 6362617   743
# 6362618   743
# 6362619   743
#
# [6362620 rows x 1 columns]

# %%
# 일부 데이터 선택 2
# 데이터프레임 -> 데이터프레임
df[['step', 'amount']]
# Out:
#          step      amount
# 0           1     9839.64
# 1           1     1864.28
# 2           1      181.00
# 3           1      181.00
# 4           1    11668.14
# ...       ...         ...
# 6362615   743   339682.13
# 6362616   743  6311409.28
# 6362617   743  6311409.28
# 6362618   743   850002.52
# 6362619   743   850002.52
#
# [6362620 rows x 2 columns]

# %%
# 일부 데이터 선택 3
# 첫 row
df.iloc[0, :]
# Out:
# step                        1
# type                  PAYMENT
# amount                9839.64
# nameOrig          C1231006815
# oldbalanceOrg          170136
# newbalanceOrig         160296
# nameDest          M1979787155
# oldbalanceDest              0
# newbalanceDest              0
# isFraud                     0
# isFlaggedFraud              0
# Name: 0, dtype: object

# %%
# 일부 데이터 선택 3
# 첫 column
df.iloc[:, 0]
# Out:
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
#           ...
# 6362615    743
# 6362616    743
# 6362617    743
# 6362618    743
# 6362619    743
# Name: step, Length: 6362620, dtype: int64

# %%
# 첫 row, column
df.iloc[0, 0]
# Out:
# 1

# %%
# 데이터 변환 1
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
columns = list(df.columns)
print(columns)
# Out:
# ['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig', 'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud', 'isFlaggedFraud']

# %%
columns[0] = 'STEP'
print(columns)
# Out:
# ['STEP', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig', 'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud', 'isFlaggedFraud']

# %%
type(columns)
# Out:
# list

# %%
df.columns = columns

# %%
df.head()
# Out:
#    STEP      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
# null value 가 있는 row 없애기
df = df.dropna()

# %%
# null value 가 있는 column 없애기
df = df.dropna(axis = 1)

# %%
# null value 를 x 로 변환하기
x = 0
df2 = df.fillna(x)

# %%
df2
# Out:
#          STEP      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
# type 변환하기
df['isFraud']
# Out:
# 0          0
# 1          0
# 2          1
# 3          1
# 4          0
#           ..
# 6362615    1
# 6362616    1
# 6362617    1
# 6362618    1
# 6362619    1
# Name: isFraud, Length: 6362620, dtype: int64

# %%
df['isFraud'].astype('object')
# Out:
# 0          0
# 1          0
# 2          1
# 3          1
# 4          0
#           ..
# 6362615    1
# 6362616    1
# 6362617    1
# 6362618    1
# 6362619    1
# Name: isFraud, Length: 6362620, dtype: object

# %%
# 고급 연산 1: filter
df['STEP'] > 10
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 6362615     True
# 6362616     True
# 6362617     True
# 6362618     True
# 6362619     True
# Name: STEP, Length: 6362620, dtype: bool

# %%
df['STEP']
# Out:
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
#           ...
# 6362615    743
# 6362616    743
# 6362617    743
# 6362618    743
# 6362619    743
# Name: STEP, Length: 6362620, dtype: int64

# %%
df[df['STEP'] > 10]
# Out:
#          STEP      type      amount     nameOrig  oldbalanceOrg  \
# 108717     11  CASH_OUT   361489.71  C1721094820       19111.00
# 108718     11  CASH_OUT   490908.50   C303404123       14688.00
# 108719     11   CASH_IN   308605.41    C47112015       53074.00
# 108720     11   PAYMENT    19598.84   C146233901     1192108.08
# 108721     11  TRANSFER   514117.49  C2130074213     1172509.23
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 108717             0.00  C1131138067            0.00        13277.21        0
# ...

# %%
# 고급 연산 2: sort 오름차순
df.sort_values('amount')
# Out:
#          STEP      type       amount     nameOrig  oldbalanceOrg  \
# 3760289   279  CASH_OUT         0.00   C539112012            0.0
# 6168500   554  CASH_OUT         0.00    C10965156            0.0
# 6362461   730  CASH_OUT         0.00   C729003789            0.0
# 2736447   212  CASH_OUT         0.00  C1510987794            0.0
# 6362463   730  CASH_OUT         0.00  C2088151490            0.0
# ...       ...       ...          ...          ...            ...
# 3911956   284  TRANSFER  69337316.27  C1584456031            0.0
# 3946920   286  TRANSFER  69886731.30  C1425667947            0.0
# 4146397   303  TRANSFER  71172480.42  C2044643633            0.0
# 4060598   300  TRANSFER  73823490.36  C2127282686            0.0
# 3686583   276  TRANSFER  92445516.64  C1715283297            0.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 3760289             0.0  C1106468520    5.385476e+05    5.385476e+05        1
# ...

# %%
# 고급 연산 2: sort 내림차순
df.sort_values('amount', ascending = False)
# Out:
#          STEP      type       amount     nameOrig  oldbalanceOrg  \
# 3686583   276  TRANSFER  92445516.64  C1715283297            0.0
# 4060598   300  TRANSFER  73823490.36  C2127282686            0.0
# 4146397   303  TRANSFER  71172480.42  C2044643633            0.0
# 3946920   286  TRANSFER  69886731.30  C1425667947            0.0
# 3911956   284  TRANSFER  69337316.27  C1584456031            0.0
# ...       ...       ...          ...          ...            ...
# 6362585   741  CASH_OUT         0.00   C312737633            0.0
# 6168500   554  CASH_OUT         0.00    C10965156            0.0
# 5563714   387  CASH_OUT         0.00  C1294472700            0.0
# 6296015   671  CASH_OUT         0.00  C1960007029            0.0
# 6281483   646  CASH_OUT         0.00  C2060908932            0.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 3686583             0.0   C439737079    9.595980e+03    9.245511e+07        0
# ...

# %%
# 고급 연산2: sort 여러 column 으로
df.sort_values(['amount', 'STEP'], ascending = [True, False])
# Out:
#          STEP      type       amount     nameOrig  oldbalanceOrg  \
# 6362585   741  CASH_OUT         0.00   C312737633            0.0
# 6362461   730  CASH_OUT         0.00   C729003789            0.0
# 6362463   730  CASH_OUT         0.00  C2088151490            0.0
# 6351226   702  CASH_OUT         0.00  C1461113533            0.0
# 6296015   671  CASH_OUT         0.00  C1960007029            0.0
# ...       ...       ...          ...          ...            ...
# 3911956   284  TRANSFER  69337316.27  C1584456031            0.0
# 3946920   286  TRANSFER  69886731.30  C1425667947            0.0
# 4146397   303  TRANSFER  71172480.42  C2044643633            0.0
# 4060598   300  TRANSFER  73823490.36  C2127282686            0.0
# 3686583   276  TRANSFER  92445516.64  C1715283297            0.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 6362585             0.0  C1400061387    2.675229e+05    2.675229e+05        1
# ...
